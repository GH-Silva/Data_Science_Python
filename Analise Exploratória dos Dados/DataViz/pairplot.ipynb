# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {
    'Preço': [20, 25, 30, 18, 22],
    'Quantidade': [100, 120, 90, 110, 105],
    'Receita': [2000, 3000, 2700, 1980, 2310]
}

# %%
df = pd.DataFrame(data)

# %%
### Criando um pairplot com Seaborn
sns.set(style='ticks')
sns.pairplot(df, diag_kind='kde')
plt.subtitle('Relações entre Preço, Quantidade e Receita', y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 sns.set(style='ticks')
#       3 sns.pairplot(df, diag_kind='kde')
# ----> 4 plt.subtitle('Relações entre Preço, Quantidade e Receita', y=1.02)
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'
